# %% [markdown]
# <a href="https://colab.research.google.com/github/azenev16/CovidGov/blob/main/Twitter_WordCloud_CovidGov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install wordcloud

# %%
import os
import matplotlib.pyplot as plt
from wordcloud.wordcloud import WordCloud

# %%
text = open('CovidResponseResult.csv',"r")
data = text.read()
print(data)
# Out:
# FALSE,42
# government,37
# pandemic,24
# covid,23
# response,14
# virus,10
# corrupt,10
# slow,8
# good,6
# health,5
# regressive,5
# lacking,4
# effective,4
# community,4
# violate,4
# poor,3
# better,3
# wisely,2
# therefore,2
# survive,2
# satisfied,2
# faceshield,2
# inefficient,2
# effectiveness,2
# complicated,1

# %%
plt.figure(figsize=(15,10))
wordcloud = WordCloud(background_color='white',mode="RGB",width =1000,height =500).generate(data)
plt.title("TOP WORD FOR COVID RESPONSES \n")
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
